# %% [markdown]
# Question no 01

# %%
nums =[1,2,3]
nums.append(10)
print(nums)
# Out:
# [1, 2, 3, 10]

# %% [markdown]
# Question no 02

# %%
order = ['burger','fries','coke','biryani']
print(order)
order.append('icecream')
print(order)
order.remove('biryani')
print(order)
# Out:
# ['burger', 'fries', 'coke', 'biryani']
# ['burger', 'fries', 'coke', 'biryani', 'icecream']
# ['burger', 'fries', 'coke', 'icecream']

# %% [markdown]
# Question no 03

# %%
nums = [4,1,3,2]
nums.sort()
print(nums)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Question no 04

# %%
passengers =['Ali','Zara','Ahmad']
passengers.insert(1,'Sara')
print(passengers)
passengers.remove('Zara')
print(passengers)
passengers.reverse()
print(passengers)
# Out:
# ['Ali', 'Sara', 'Zara', 'Ahmad']
# ['Ali', 'Sara', 'Ahmad']
# ['Ahmad', 'Sara', 'Ali']

# %% [markdown]
# Question no 05

# %%
text ='Hello Python World'
text = text.replace(' ' , '_')
print(text)
text= text.split('_')
print(text)
print('-'.join(text))
# Out:
# Hello_Python_World
# ['Hello', 'Python', 'World']
# Hello-Python-World

# %% [markdown]
# Question no 06

# %%
word ='javascript'
print(len(word)>5)
# Out:
# True

# %% [markdown]
# Question no 07

# %%
code ='SKU-12345-XYZ'
print(code.find('-'))
print(code.count('-'))
print(code.removeprefix('SKU-'))
print(code.removesuffix('-XYZ'))
result = code.split('-')
print(result)
print(result[1])
# Out:
# 3
# 2
# 12345-XYZ
# SKU-12345
# ['SKU', '12345', 'XYZ']
# 12345

# %% [markdown]
# Question no 08

# %%
cities = ['Karachi','Lahore','Islamabad','Quetta']
cities.reverse()
print(cities)
# Out:
# ['Quetta', 'Islamabad', 'Lahore', 'Karachi']

# %% [markdown]
# Question no 09

# %%
text = ' Data Analysis with Python is very powerful '
text = text.strip()
print(text)
print(text.title())
text = text.replace('powerful','Important')
print(text)
# Out:
# Data Analysis with Python is very powerful
# Data Analysis With Python Is Very Powerful
# Data Analysis with Python is very Important

# %% [markdown]
# Question no 10

# %%
data = [12,45,2,67,34,89,23,90]
data.sort()
print(data)
data.remove(max(data))
print(data)
data.insert(3,50)
print(data)
data.reverse()
print(data)
# Out:
# [2, 12, 23, 34, 45, 67, 89, 90]
# [2, 12, 23, 34, 45, 67, 89]
# [2, 12, 23, 50, 34, 45, 67, 89]
# [89, 67, 45, 34, 50, 23, 12, 2]
