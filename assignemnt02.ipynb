# %% [markdown]
# #### Question 1
#
# ##### Calculate and write the output of the following expression:
# **30 + 4 × 3 − 6**

# %%
print(30 + 4 * 3- 6)
# Out:
# 36

# %% [markdown]
# #### Question 2
#
# ##### Calculate and write the output of the following expression:
# **100 ÷ 4 + 7 − 5**

# %%
print(100 / 4 + 7 - 5)
# Out:
# 27.0

# %% [markdown]
# #### Question 3
#
# ##### Create a variable containing the string value "100". Convert it into an integer and display its data type before and after conversion.

# %%
value = "100"
print(type(value))
value = int(value)
print(type(value))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# #### Question 4
#
# ##### Create the following list and display:
# ##### cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
# ##### Second city
# ##### Fourth city

# %%
cities =["Karachi","Lahore","Peshawar","Islamabad","Quetta"]
print(cities[1])
print(cities[3])
# Out:
# Lahore
# Islamabad

# %% [markdown]
# #### Question 5
# ##### Create the following nested list and display:
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Ali
# ##### Ayesha

# %%
students = [["Ali",20],["Ayesha",22],["Ahmed", 21]]
print(students[0][0])
print(students[1][0])
# Out:
# Ali
# Ayesha

# %% [markdown]
# #### Question 6
# ##### Given list:
# ##### numbers = [10, 20, 30, 40, 50, 60, 70]
# ##### Display:
# ##### First 3 elements
# ##### Last 3 elements

# %%
numbers = [ 10, 20 ,30 ,40 ,50 ,60 ,70]
print(numbers[:3])
print(numbers[-3:])
# Out:
# [10, 20, 30]
# [50, 60, 70]

# %% [markdown]
# #### Question 7
# ##### Given nested list::
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Display:
# ##### Name of first student
# ##### Age of second student

# %%
students = [["Ali",20],["Ayesha",22],["Ahmed", 21]]
print(students[0][0])
print(students[1][1])
# Out:
# Ali
# 22

# %% [markdown]
# #### Question 8
# ##### Create a list of 5 fruits and display:
# ##### First fruit
# ##### Last fruit

# %%
fruits = ["mango","banana","lychee","pineapple","strawberry"]
print(fruits[0])
print(fruits[-1])
# Out:
# mango
# strawberry

# %% [markdown]
# #### Question 9
# ##### Create the following list and display:
# ##### colors = ["Red", "Blue", "Green", "Yellow", "Black"]
# ##### First color
# ##### Last color
# ##### using negative indexing

# %%
color =["red", "blue", "green" , "yellow", "black"]
print(color[0])
print(color[-1])
# Out:
# red
# black

# %% [markdown]
# #### Question 10
# ##### Given nested list:
# ##### marks = [["Math", 90], ["Physics", 85], ["English", 88]]
# ##### Display:
# ##### Subject of second student
# ##### Marks of third student

# %%
marks = [["Maths",90],["Physics",85],["English",88]]
print(marks[1][0])
print(marks[2][1])
# Out:
# Physics
# 88
